# %%
import pandas
import pandas as pd
import sklearn.model_selection
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt

data = pandas.read_csv("StudentPerformanceFactorsPuhas.csv", sep=";")

data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6373             25          69                 High              Medium
# 6374             23          76                 High              Medium
# 6375             20          90               Medium                 Low
# 6376             10          86                 High                High
# 6377             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6373                         No            7               76
# 6374                         No            8               81
# 6375                        Yes            6               65
# 6376                        Yes            6               91
# 6377                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6373           Medium             Yes                  1          High
# 6374           Medium             Yes                  3           Low
# 6375              Low             Yes                  3           Low
# 6376             High             Yes                  2           Low
# 6377           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6373          Medium      Public       Positive                  2
# 6374            High      Public       Positive                  2
# 6375          Medium      Public       Negative                  2
# 6376          Medium     Private       Positive                  3
# 6377          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6373                    No              High School               Near
# 6374                    No              High School               Near
# 6375                    No             Postgraduate               Near
# 6376                    No              High School                Far
# 6377                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6373  Female          68
# 6374  Female          69
# 6375  Female          68
# 6376  Female          68
# 6377    Male          64
#
# [6378 rows x 20 columns]

# %%
data = pandas.get_dummies(data, columns=data.columns[(data.dtypes == 'object') | (data.dtypes == 'category')])
data
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6373             25          69            7               76
# 6374             23          76            8               81
# 6375             20          90            6               65
# 6376             10          86            6               91
# 6377             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score  \
# 0                     0                  3          67
# 1                     2                  4          61
# 2                     2                  4          74
# 3                     1                  4          71
# 4                     3                  4          70
# ...                 ...                ...         ...
# 6373                  1                  2          68
# 6374                  3                  2          69
# 6375                  3                  2          68
# 6376                  2                  3          68
# 6377                  0                  4          64
#
#       Parental_Involvement_High  Parental_Involvement_Low  \
# 0                         False                      True
# 1                         False                      True
# 2                         False                     False
# 3                         False                      True
# 4                         False                     False
# ...                         ...                       ...
# 6373                       True                     False
# 6374                       True                     False
# 6375                      False                     False
# 6376                       True                     False
# 6377                      False                     False
#
#       Parental_Involvement_Medium  ...  Learning_Disabilities_No  \
# 0                           False  ...                      True
# 1                           False  ...                      True
# 2                            True  ...                      True
# 3                           False  ...                      True
# 4                            True  ...                      True
# ...                           ...  ...                       ...
# 6373                        False  ...                      True
# 6374                        False  ...                      True
# 6375                         True  ...                      True
# 6376                        False  ...                      True
# 6377                         True  ...                      True
#
#       Learning_Disabilities_Yes  Parental_Education_Level_College  \
# 0                         False                             False
# 1                         False                              True
# 2                         False                             False
# 3                         False                             False
# 4                         False                              True
# ...                         ...                               ...
# 6373                      False                             False
# 6374                      False                             False
# 6375                      False                             False
# 6376                      False                             False
# 6377                      False                             False
#
#       Parental_Education_Level_High School  \
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
# ...                                    ...
# 6373                                  True
# 6374                                  True
# 6375                                 False
# 6376                                  True
# 6377                                 False
#
#       Parental_Education_Level_Postgraduate  Distance_from_Home_Far  \
# 0                                     False                   False
# 1                                     False                   False
# 2                                      True                   False
# 3                                     False                   False
# 4                                     False                   False
# ...                                     ...                     ...
# 6373                                  False                   False
# 6374                                  False                   False
# 6375                                   True                   False
# 6376                                  False                    True
# 6377                                   True                   False
#
#       Distance_from_Home_Moderate  Distance_from_Home_Near  Gender_Female  \
# 0                           False                     True          False
# 1                            True                    False           True
# 2                           False                     True          False
# 3                            True                    False          False
# 4                           False                     True           True
# ...                           ...                      ...            ...
# 6373                        False                     True           True
# 6374                        False                     True           True
# 6375                        False                     True           True
# 6376                        False                    False           True
# 6377                        False                     True          False
#
#       Gender_Male
# 0            True
# 1           False
# 2            True
# 3            True
# 4           False
# ...           ...
# 6373        False
# 6374        False
# 6375        False
# 6376        False
# 6377         True
#
# [6378 rows x 41 columns]

# %%
x = data.drop("Exam_Score", axis=1)
y = data["Exam_Score"]
print(x.shape,
y.shape)
X_train_val, X_test, y_train_val, y_test = sklearn.model_selection.train_test_split(x, y, train_size=0.8)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X_train_val, y_train_val, train_size=0.8)
# Out:
# (6378, 40) (6378,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model = KNeighborsClassifier(n_neighbors=10, metric="euclidean")
model.fit(X_train, y_train)
accuracy = accuracy_score(y_test, model.predict(X_test))
accuracy
# Out:
# 0.19827586206896552

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
accuracy = accuracy_score(y_test, model.predict(X_test))
accuracy
# Out:
# 0.19905956112852666

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, max_depth=10)
model.fit(X_train, y_train)
accuracy = accuracy_score(y_test, model.predict(X_test))
accuracy
# Out:
# 0.2249216300940439

# %%
from sklearn.svm import SVC

model = SVC(kernel="linear", degree=2, gamma="auto")
model.fit(X_train, y_train)
accuracy = accuracy_score(y_val, model.predict(X_val))
accuracy
# Out:
# 0.8188050930460333

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd

model = RandomForestRegressor()
model.fit(X_train, y_train)
pred = model.predict(X_val)
mse = mean_squared_error(y_val, pred)
print(f'Mean Squared Error: {mse}')

importances = model.feature_importances_
feature_importance_df = pd.DataFrame({"Feature": X_train.columns, "Importance": importances})
print(feature_importance_df)
# Out:
# Mean Squared Error: 3.5969939275220373
#                                   Feature  Importance
# 0                           Hours_Studied    0.239291
# 1                              Attendance    0.381078
# 2                             Sleep_Hours    0.023652
# 3                         Previous_Scores    0.081617
# 4                       Tutoring_Sessions    0.026983
# 5                       Physical_Activity    0.027437
# 6               Parental_Involvement_High    0.015977
# 7                Parental_Involvement_Low    0.014159
# 8             Parental_Involvement_Medium    0.003578
# 9                Access_to_Resources_High    0.014993
# 10                Access_to_Resources_Low    0.014225
# 11             Access_to_Resources_Medium    0.004837
# 12          Extracurricular_Activities_No    0.005692
# 13         Extracurricular_Activities_Yes    0.003386
# 14                  Motivation_Level_High    0.007459
# 15                   Motivation_Level_Low    0.006541
# 16                Motivation_Level_Medium    0.003782
# 17                     Internet_Access_No    0.003371
# 18                    Internet_Access_Yes    0.003312
# 19                     Family_Income_High    0.008704
# 20                      Family_Income_Low    0.006332
# 21                   Family_Income_Medium    0.003791
# 22                   Teacher_Quality_High    0.007810
# 23                    Teacher_Quality_Low    0.003812
# 24                 Teacher_Quality_Medium    0.004986
# 25                    School_Type_Private    0.002371
# 26                     School_Type_Public    0.003199
# 27                Peer_Influence_Negative    0.006502
# 28                 Peer_Influence_Neutral    0.005221
# 29                Peer_Influence_Positive    0.007047
# 30               Learning_Disabilities_No    0.004816
# 31              Learning_Disabilities_Yes    0.004667
# 32       Parental_Education_Level_College    0.005657
# 33   Parental_Education_Level_High School    0.006441
# 34  Parental_Education_Level_Postgraduate    0.011365
# 35                 Distance_from_Home_Far    0.007507
# 36            Distance_from_Home_Moderate    0.003506
# 37                Distance_from_Home_Near    0.006814
# 38                          Gender_Female    0.004140
# 39                            Gender_Male    0.003942

# %%
data["Exam_Score"].value_counts()
# Out:
# Exam_Score
# 68     738
# 66     722
# 67     692
# 65     650
# 69     599
# 70     526
# 64     478
# 71     398
# 63     350
# 72     298
# 62     261
# 61     166
# 73     133
# 74     102
# 60      75
# 75      48
# 59      39
# 58      21
# 76      16
# 80       5
# 77       5
# 94       4
# 86       4
# 82       4
# 78       4
# 57       4
# 84       3
# 79       3
# 89       3
# 98       3
# 88       3
# 97       3
# 95       2
# 93       2
# 87       2
# 99       2
# 92       2
# 83       1
# 100      1
# 55       1
# 101      1
# 91       1
# 96       1
# 85       1
# 56       1
# Name: count, dtype: int64
